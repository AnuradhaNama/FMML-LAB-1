# %% [markdown]
# <a href="https://colab.research.google.com/github/AnuradhaNama/FMML-MODULES/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-30 16:15:26--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   199MB/s    in 0.3s
#
# 2024-03-30 16:15:26 (199 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3361 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 6581   1703.07345v2  The cardinality constraint is an intrinsic way...    cs
# 22683  1704.02916v2  The standard interpretation of importance-weig...  stat
# 21535   0912.0171v2  This article addresses the modeling of reverbe...  stat
# 24836   1412.1957v1  Feature or interest points typically use infor...    cs
# 4486   cs/0302015v1  This paper describes a novel approach to unsup...    cs
# ...             ...                                                ...   ...
# 29565  1709.07993v1  Pulmonary embolism (PE) is a highly mortal dis...    cs
# 10818   1408.0055v1  We introduce Thurstonian Boltzmann Machines (T...  stat
# 6947   1707.09641v2  The predictive power of neural networks often ...    cs
# 22484  1609.05057v2  Sparse subspace clustering (SSC) is an elegant...  stat
# 17544  1712.01460v1  In recent years, word embeddings have been sur...    cs
#
#                                                    title  year  \
# 6581   On The Projection Operator to A Three-view Car...  2017
# 22683    Reinterpreting Importance-Weighted Autoencoders  2017
# 21535  Under-determined reverberant audio source sepa...  2009
# 24836  CoMIC: Good features for detection and matchin...  2014
# 4486   Unsupervised Learning in a Framework of Inform...  2003
# ...                                                  ...   ...
# 29565  A semi-automated segmentation method for detec...  2017
# 10818  Thurstonian Boltzmann Machines: Learning from ...  2014
# 6947   Towards Visual Explanations for Convolutional ...  2017
# 22484  Unbiased Sparse Subspace Clustering By Selecti...  2016
# 17544  AWE-CM Vectors: Augmenting Word Embeddings wit...  2017
#
#                                                 keywords
# 6581   [cardinality, constraint, intrinsic, structure...
# 22683  [interpretation, importance, autoencoders, lik...
# 21535  [addresses, reverberant, recording, environmen...
# 24836  [typically, information, aggregation, boundari...
# 4486   [describes, unsupervised, developed, framework...
# ...                                                  ...
# 29565  [pulmonary, currently, pulmonary, angiography,...
# 10818  [introduce, thurstonian, boltzmann, architectu...
# 6947   [predictive, interpretability, techniques, dev...
# 22484  [clustering, unsupervised, segmentation, subsp...
# 17544  [embeddings, surprisingly, effective, capturin...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 6581     [cardinality, constraint, intrinsic, structure...
# 22683    [interpretation, importance, autoencoders, lik...
# 21535    [addresses, reverberant, recording, environmen...
# 24836    [typically, information, aggregation, boundari...
# 4486     [describes, unsupervised, developed, framework...
#                                ...
# 2245     [typically, proprietary, transparent, distilla...
# 11667    [relationship, regression, algorithms, posteri...
# 35993    [optimisation, interacting, components, differ...
# 10464    [generative, typically, committed, assumptions...
# 32850    [algorithm, regularization, flexibility, poten...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8750 words.
# Out of those 4600 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="749e5d48-079e-48d3-9895-be103d98f516" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("749e5d48-079e-48d3-9895-be103d98f516")) {                    Plotly.newPlot(                        "749e5d48-079e-48d3-9895-be103d98f516",                        [{"x":["constraints","compressed","challenge","variables","constrained","regulatory","interesting","overlapped","bioinformatics","synthetic","structure","complexity","projection","cardinality","intrinsic","assignment","experiments","proportional","applications","restriction","programming","identification","crowdsourcing","selection","constraint","alternate","likelihood","distribution","importance","autoencoders","interpretation","variational","visualize","procedure","optimizes","determined","contribution","characteristics","directions","covariance","procedures","experimental","recording","including","estimated","effectiveness","separation","reverberant","iterative","environments","algorithms","frequency","parameters","addresses","unconstrained","initialize","recordings","sequences","associated","conditions","background","intensity","comparably","typically","maximally","detectors","exhaustive","illustrated","especially","significantly","information","detection","performing","aggregation","boundaries","unsupervised","developed","unification","alignment","production","framework","probabilistic","describes","recognition","reasoning","compression","functions","integrate","outperforms","generalized","instances","structural","performance","prototypes","combination","synthesized","implement","embedding","geometric","alleviate","meaningful","clustering","inconsistency","classified","prototype","specifically","reconstruction","knowledge","recognize","transferring","discovered","interprets","stochastic","characterized","textitfixed","successive","strategies","algorithm","therefore","confidence","probability","rejection","relativity","dimensional","effective","empirical","appropriate","mathematical","validates","asymptotic","theoretical","efficient","construct","thresholding","estimation","additionally","properties","particular","conjugate","coordinate","relationship","practical","equivalent","different","dramatically","regularization","conventional","normalization","difficult","modifying","outperforming","baselines","validated","techniques","improving","technique","statistical","approximate","displaying","thoroughly","breakthroughs","significance","demonstrate","approaches","normalized","uncertainty","competitive","inference","architectures","estimates","generative","optimization","formulate","representational","autoencoder","corroborated","adversarial","densities","estimating","minimization","extensive","investigate","considered","sufficient","compressive","generalization","minimizer","nonlinear","collection","semantics","relatively","recurrent","numerically","grammatical","evaluation","quantities","improvements","important","groundings","conditioning"],"y":[153,30,159,101,69,6,73,5,15,142,342,239,53,10,54,30,611,10,449,10,143,100,11,157,85,7,84,240,87,30,62,54,12,130,23,30,60,85,40,20,31,374,12,233,60,203,20,1,79,91,637,50,257,56,19,6,7,90,113,144,80,27,9,97,14,36,13,21,135,285,670,368,74,28,29,162,184,8,52,21,561,174,71,355,131,36,233,43,252,78,78,73,890,5,139,22,69,86,65,24,61,164,7,27,28,172,105,376,50,11,29,3,115,29,0,16,89,838,140,37,166,1,1,202,264,154,88,61,2,15,152,435,87,23,208,73,198,282,10,29,83,133,64,724,27,78,109,32,171,13,22,63,32,370,95,264,144,110,0,14,3,23,572,412,29,89,112,221,136,71,121,333,56,14,24,3,108,15,65,69,185,123,115,85,13,108,4,57,69,99,52,148,11,17,223,18,102,352,2,19],"type":"bar"},{"x":["constraints","compressed","challenge","variables","constrained", ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4600,), (4600, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7933333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Auditing</span> <span style=''>Active</span> <span style=''>Learning</span> <span style=''>with</span> <span style=''>Outcome</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Dependent</span> <span style=''>Query</span> <span style=''>Costs</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>learning</span> <span style=''>setting</span> <span style=''>in</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unlabeled</span> <span style=''>data</span> <span style=''>is</span> <span style=''>free</span> <span style=''>and</span> <span style=''>the</span> <span style=''>cost</span> <span style=''>of</span> <span style=''>a</span> <span style=''>label</span> <span style=''>depends</span> <span style=''>on</span> <span style=''>its</span> <span style=''>value</span> <span style=''>which</span> <span style=''>is</span> <span style=''>not</span> <span style=''>known</span> <span style=''>in</span> <span style=''>advance</span> <span style=''>We</span> <span style=''>study</span> <span style=''>binary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>in</span> <span style=''>an</span> <span style=''>extreme</span> <span style=''>case</span> <span style=''>where</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>only</span> <span style=''>pays</span> <span style=''>for</span> <span style=''>negative</span> <span style=''>labels</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>motivation</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>such</span> <span style=''>as</span> <span style=''>fraud</span> <span style='background-color:rgba(0, 255, 0, 0.5593220338983051);'>detection</span> <span style=''>in</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>investigating</span> <span style=''>an</span> <span style=''>honest</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transaction</span> <span style=''>should</span> <span style=''>be</span> <span style=''>avoided</span> <span style=''>if</span> <span style=''>possible</span> <span style=''>We</span> <span style=''>term</span> <span style=''>the</span> <span style=''>setting</span> <span style=''>auditing</span> <span style=''>and</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>auditing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>of</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>negative</span> <span style=''>labels</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>requires</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style=''>with</span> <span style=''>low</span> <span style=''>relative</span> <span style=''>error</span> <span style=''>We</span> <span style=''>design</span> <span style=''>auditing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>simple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style=''>classes</span> <span style=''>(thresholds</span> <span style=''>and</span> <span style=''>rectangles)</span> <span style=''>and</span> <span style=''>show</span> <span style=''>that</span> <span style=''>with</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>the</span> <sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>definition</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>confounder</span> <br/><br/><span style=''>The</span> <span style=''>causal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>literature</span> <span style=''>has</span> <span style=''>provided</span> <span style=''>a</span> <span style=''>clear</span> <span style=''>formal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>definition</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>confounding</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expressed</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>counterfactual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independence</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>literature</span> <span style=''>has</span> <span style=''>not</span> <span style=''>however</span> <span style=''>come</span> <span style=''>to</span> <span style=''>any</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consensus</span> <span style=''>on</span> <span style=''>a</span> <span style=''>formal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>definition</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>confounder</span> <span style=''>as</span> <span style=''>it</span> <span style=''>has</span> <span style=''>given</span> <span style=''>priority</span> <span style=''>to</span> <span style=''>the</span> <span style=''>concept</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>confounding</span> <span style=''>over</span> <span style=''>that</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>confounder</span> <span style=''>We</span> <span style=''>consider</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>candidate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>definitions</span> <span style=''>arising</span> <span style=''>from</span> <span style=''>various</span> <span style=''>more</span> <span style=''>informal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>statements</span> <span style=''>made</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>literature</span> <span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>satisfied</span> <span style=''>by</span> <span style=''>each</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>candidate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>definition</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>principally</span> <span style=''>focusing</span> <span style=''>on</span> <span style=''>(i)</span> <span style=''>whether</span> <span style=''>under</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>candidate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>definition</span> <span style=''>control</span> <span style=''>for</span> <span style=''>all</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>confounders</span> <span style=''>suffices</span> <span style=''>to</span> <span style=''>control</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>confounding</span> <span style=''>and</span> <span style=''>(ii)</span> <span style=''>whether</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.43065693430656937);'>Regularized</span> <span style=''>Maximum</span> <span style='background-color:rgba(255, 0, 0, 0.4166666666666667);'>Likelihood</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Intrinsic</span> <span style='background-color:rgba(255, 0, 0, 0.32444444444444437);'>Dimension</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Estimation</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.31578947368421045);'>estimating</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intrinsic</span> <span style='background-color:rgba(255, 0, 0, 0.32444444444444437);'>dimension</span> <span style=''>of</span> <span style=''>a</span> <span style=''>dataset</span> <span style=''>by</span> <span style=''>applying</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principle</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.43065693430656937);'>regularized</span> <span style=''>maximum</span> <span style='background-color:rgba(255, 0, 0, 0.4166666666666667);'>likelihood</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.30303030303030304);'>distances</span> <span style=''>between</span> <span style=''>close</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>neighbors</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.383399209486166);'>regularization</span> <span style=''>scheme</span> <span style=''>which</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>motivated</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.452054794520548);'>divergence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principles</span> <span style=''>We</span> <span style=''>derive</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.6551724137931034);'>estimator</span> <span style=''>by</span> <span style=''>a</span> <span style=''>Poisson</span> <span style=''>process</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>argue</span> <span style=''>about</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3236994219653179);'>convergence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>and</span> <span style=''>apply</span> <span style=''>it</span> <span style=''>to</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.4134615384615384);'>simulated</span> <span style=''>and</span> <span style=''>real</span> <span style=''>datasets</span> <span style=''>We</span> <span style=''>also</span> <span style=''>show</span> <span style=''>it</span> <span style=''>has</span> <span style=''>the</span> <span style=''>best</span> <span style=''>overall</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>compared</span> <span style=''>with</span> <span style=''>two</span> <span style=''>other</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intrinsic</span> <span style='background-color:rgba(255, 0, 0, 0.32444444444444437);'>dimension</span> <span style='background-color:rgba(255, 0, 0, 0.6170212765957446);'>estimators</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connection</span> <span style=''>center</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evolution</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>determination</span> <span style=''>of</span> <span style=''>cluster</span> <span style=''>centers</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generally</span> <span style=''>depends</span> <span style=''>on</span> <span style=''>the</span> <span style=''>scale</span> <span style=''>that</span> <span style=''>we</span> <span style=''>use</span> <span style=''>to</span> <span style=''>analyze</span> <span style=''>the</span> <span style=''>data</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustered</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inappropriate</span> <span style=''>scale</span> <span style=''>usually</span> <span style=''>leads</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unreasonable</span> <span style=''>cluster</span> <span style=''>centers</span> <span style=''>and</span> <span style=''>thus</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unreasonable</span> <span style=''>results</span> <span style=''>In</span> <span style=''>this</span> <span style=''>study</span> <span style=''>we</span> <span style=''>first</span> <span style=''>consider</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>of</span> <span style=''>elements</span> <span style=''>in</span> <span style=''>the</span> <span style=''>data</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connectivity</span> <span style=''>of</span> <span style=''>nodes</span> <span style=''>in</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>undirected</span> <span style=''>graph</span> <span style=''>then</span> <span style=''>present</span> <span style=''>the</span> <span style=''>concept</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connection</span> <span style=''>center</span> <span style=''>and</span> <span style=''>regard</span> <span style=''>it</span> <span style=''>as</span> <span style=''>the</span> <span style=''>cluster</span> <span style=''>center</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>Based</span> <span style=''>on</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>definition</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>determination</span> <span style=''>of</span> <span style=''>cluster</span> <span style=''>centers</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assignment</span> <span style=''>of</span> <span style=''>class</span> <span style=''>are</span> <span style=''>very</span> <span style=''>simple</span> <span style=''>natural</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style=''>One</span> <span style=''>more</span> <span style=''>crucial</span> <span style=''>finding</span> <span style=''>is</span> <span style=''>that</span> <span style=''>the</span> <span style=''>cluster</span> <span style=''>centers</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>scales</span> <span style=''>can</span> <span style=''>be</span> <span style=''>obtained</span> <span style=''>easily</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <s ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12366737739872068)
# 	architecture (0.08422174840085288)
# 	information (0.23809523809523808)
# 	segmentation (0.07036247334754797)
# 	experimental (0.13290689410092396)
# 	knowledge (0.13361762615493958)
# 	different (0.2572850035536603)
# 	detection (0.13077469793887705)
# 	recognition (0.1261549395877754)
# 	convolutional (0.13930348258706468)
#
# Some Statistics words are:
# 	algorithm (0.39123867069486407)
# 	stochastic (0.13494461228600202)
# 	estimation (0.17270896273917422)
# 	distribution (0.18429003021148035)
# 	theoretical (0.15508559919436052)
# 	statistical (0.15861027190332327)
# 	variables (0.14803625377643503)
# 	dimensional (0.19184290030211482)
# 	inference (0.20644511581067473)
# 	regression (0.18177240684793555)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a2293afb-5f48-41ad-b48c-aae4bfcb7a41" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a2293afb-5f48-41ad-b48c-aae4bfcb7a41")) {                    Plotly.newPlot(                        "a2293afb-5f48-41ad-b48c-aae4bfcb7a41",                        [{"x":["constraints","compressed","challenge","variables","constrained","regulatory","interesting","overlapped","bioinformatics","synthetic","structure","complexity","projection","cardinality","intrinsic","assignment","experiments","proportional","applications","restriction","programming","identification","crowdsourcing","selection","constraint","alternate","likelihood","distribution","importance","autoencoders","interpretation","variational","visualize","procedure","optimizes","determined","contribution","characteristics","directions","covariance","procedures","experimental","recording","including","estimated","effectiveness","separation","reverberant","iterative","environments","algorithms","frequency","parameters","addresses","unconstrained","initialize","recordings","sequences","associated","conditions","background","intensity","comparably","typically","maximally","detectors","exhaustive","illustrated","especially","significantly","information","detection","performing","aggregation","boundaries","unsupervised","developed","unification","alignment","production","framework","probabilistic","describes","recognition","reasoning","compression","functions","integrate","outperforms","generalized","instances","structural","performance","prototypes","combination","synthesized","implement","embedding","geometric","alleviate","meaningful","clustering","inconsistency","classified","prototype","specifically","reconstruction","knowledge","recognize","transferring","discovered","interprets","stochastic","characterized","textitfixed","successive","strategies","algorithm","therefore","confidence","probability","rejection","relativity","dimensional","effective","empirical","appropriate","mathematical","validates","asymptotic","theoretical","efficient","construct","thresholding","estimation","additionally","properties","particular","conjugate","coordinate","relationship","practical","equivalent","different","dramatically","regularization","conventional","normalization","difficult","modifying","outperforming","baselines","validated","techniques","improving","technique","statistical","approximate","displaying","thoroughly","breakthroughs","significance","demonstrate","approaches","normalized","uncertainty","competitive","inference","architectures","estimates","generative","optimization","formulate","representational","autoencoder","corroborated","adversarial","densities","estimating","minimization","extensive","investigate","considered","sufficient","compressive","generalization","minimizer","nonlinear","collection","semantics","relatively","recurrent","numerically","grammatical","evaluation","quantities","improvements","important","groundings","conditioning","incomplete","numerical","correction","perplexity","generally","grounding","conditioned","architecture","artificial","structures","relevance","understood","intuitively","connections","amplified","connectivity","hierarchical","benchmark","otherwise","directional","validation","compresses","favorable","formulations","repositories","sparsifying","interested","principle","sparsification","description","approximations","principled","regression","preserving","restricted","requiring","automatic","residuals","expansion","limitations","automates","predicting","recognized","appropriately","representing","averaging","returning","substituting","classification","overcoming","dependent","regressors","sensitive","covariates","ignorance","available","d ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	textitfixed
# 	displaying
# 	automates
# 	substituting
# 	semiparametric
# 	respondents
# 	isometric
# 	hydraulic
# 	discriminable
# 	reconstructive
# 	impulsive
# 	unregularized
# 	ultrametric
# 	clusterings
# 	purchasing
# 	complications
# 	emphsparse
# 	pessimistic
# 	mcdiarmids
# 	scleroderma
# Some words which never appear in Statistics papers:
# 	overlapped
# 	interprets
# 	corroborated
# 	grammatical
# 	groundings
# 	amplified
# 	recompute
# 	alternately
# 	participant
# 	relatedness
# 	polysemous
# 	disambiguation
# 	invisible
# 	refinenet
# 	keypoints
# 	crossover
# 	prerequisite
# 	shortening
# 	paraphrasing
# 	substrate

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0543677458766035e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7591666666666667
